# %% [markdown]
# Extract text and selected metadata from [PubMed Central](https://www.ncbi.nlm.nih.gov/pmc/) articles.

# %%
DATA_DIR = "D:/ml_data/pubmed/"
DATA_FILE = "pmc_result_vaccine_allergy_1year.xml"  # 758MB

# %%
import xml.etree.ElementTree as ET
tree = ET.parse(DATA_DIR + DATA_FILE)
articles =  tree.getroot().findall('article')

# %%
import pandas as pd


def print_tag_hierarchy(e, depth=0):
    indent = ''.join(['.' for i in range(depth)])
    print(indent, e.tag)
    for child in e:
        print_tag_hierarchy(child, depth + 1)


def get_section_text(sec, header_path=[]):
    # sec elements can be nested.
    # Here I assume all narrative text is within <p> elements.
    my_header_path = header_path.copy()
    title_element = sec.find('title')
    if title_element is not None:  # type(title_element) != type(None): 'NoneType':
        my_header_path.append( ''.join(title_element.itertext()) ) 
    my_title = ' || '.join(my_header_path)  # flattened path for (sub)section header
    results = [] # list of tuples (title, text) tuples
    for child in sec:
        if child.tag == 'p':
            results.append( tuple(( my_title, ''.join(child.itertext()) )) )
        elif child.tag == 'sec': # subsection
            subsection_results = get_section_text(child, my_header_path)
            for ssres in subsection_results:
                results.append(ssres)
    
    return results


def get_title(art):
    title = 'MISSING'
    title_list = art.findall("front/article-meta/title-group/article-title")
    if len(title_list) > 0:
        title = ''.join(title_list[0].itertext())
    return title


def get_abstract(art):
    abstract = 'MISSING'
    abstract_element = art.find("front/article-meta/abstract")
    results = []
    if abstract_element is not None:
        for c in abstract_element:
            if c.tag == 'p':
                t = ''.join( [t for t in c.itertext()])
                results.append( tuple(( 'Abstract', t )) )
            elif c.tag == 'sec':
                sub_results = get_section_text(c, ['Abstract'])
                for sr in sub_results:
                    results.append(sr)
    return results


def get_article_id(art):
    art_id_list = art.findall('front/article-meta/article-id')
    # art_ids = []
    # for aid in art_id_list:
    #     if aid.attrib['pub-id-type'] == 'pmid':
    #         art_ids.append(f"pmid:{aid.text}")
    #     if aid.attrib['pub-id-type'] == 'pmc':
    #         art_ids.append(f"pmc:{aid.text}")
    # return '||'.join(art_ids)
    pmid = 'MISSING'
    for aid in art_id_list:
        if aid.attrib['pub-id-type'] == 'pmid':
            pmid = aid.text
            break
    return pmid
    

def get_article_text(art):
    """
    art: an ElementTree representng an article from Pubmed Central results
    Returns a list with one tuple for each paragraph in each section in an article. 
    The elements of each tuple are a flattened section heading path and a paragraph text string.
    """
    results = []

    results.append( tuple(( 'Title', get_title(art) )) )

    abstract_rows = get_abstract(art)
    for abrow in abstract_rows:
        results.append(abrow)
    
    for sec in art.findall('body/sec'):
        for ssres in get_section_text(sec):
            results.append(ssres)
            
    return results


def get_all_articles(articles):
    results = []
    for art in articles:
        art_id = get_article_id(art)
        art_rows = get_article_text(art)
        paragraph_number = 0
        for arow in art_rows:
            results.append( tuple((art_id, paragraph_number, arow[0], arow[1])) )
            paragraph_number += 1
    return pd.DataFrame(results, columns=['pmid', 'paragraph_number', 'section_path', 'text'])

# %%
# Examine the tag tree for one article

print_tag_hierarchy( articles[0] )
# Out:
#  article
# . processing-meta
# .. restricted-by
# . front
# .. journal-meta
# ... journal-id
# ... journal-id
# ... journal-id
# ... journal-id
# ... journal-title-group
# .... journal-title
# ... issn
# ... issn
# ... publisher
# .... publisher-name
# .... publisher-loc
# .. article-meta
# ... article-id
# ... article-id
# ... article-id
# ... article-id
# ... article-id
# ... article-categories
# .... subj-group
# ..... subject
# .... subj-group
# ..... subject
# ... title-group
# .... article-title
# ..... styled-content
# .... alt-title
# ... contrib-group
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... contrib-id
# ..... xref
# ...... sup
# ..... address
# ...... email
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... contrib-id
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... contrib-id
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ...... suffix
# ..... contrib-id
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... contrib-id
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... contrib-id
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# .... contrib
# ..... name
# ...... surname
# ...... given-names
# ..... xref
# ...... sup
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... institution
# .... city
# .... named-content
# .... country
# ... aff
# .... label
# ..... sup
# .... named-content
# .... institution
# .... city
# .... named-content
# .... country
# ... author-notes
# .... corresp
# ..... label
# ..... bold
# ..... break
# ..... break
# ..... email
# ..... break
# ... pub-date
# .... day
# .... month
# .... year
# ... pub-date
# .... month
# .... year
# ... pub-date
# .... day
# .... month
# .... year
# ... volume
# ... issue
# ... issue-id
# ... fpage
# ... lpage
# ... history
# .... date
# ..... day
# ..... month
# ..... year
# .... date
# ..... day
# ..... month
# ..... year
# .... date
# ..... day
# ..... month
# ..... year
# ... permissions
# .... copyright-statement
# .... license
# ..... license-p
# ... self-uri
# ... abstract
# .... title
# .... p
# ... kwd-group
# .... kwd
# .... kwd
# .... kwd
# .... kwd
# .... kwd
# ... counts
# .... fig-count
# .... table-count
# .... page-count
# .... word-count
# ... custom-meta-group
# .... custom-meta
# ..... meta-name
# ..... meta-value
# .... custom-meta
# ..... meta-name
# ..... meta-value
# .... custom-meta
# ..... meta-name
# ..... meta-value
# .. notes
# ... p
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ...... styled-content
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# . body
# .. def-list
# ... title
# ... def-item
# .... term
# .... def
# ..... p
# ... def-item
# .... term
# .... def
# ..... p
# ... def-item
# .... term
# .... def
# ..... p
# ... def-item
# .... term
# .... def
# ..... p
# ... def-item
# .... term
# .... def
# ..... p
# .. sec
# ... label
# ... title
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .. sec
# ... label
# ... title
# ... p
# .... xref
# ..... sup
# ... p
# .... xref
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... fig
# .... label
# .... caption
# ..... p
# .... graphic
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... italic
# .... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .. sec
# ... label
# ... title
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# .... xref
# .... xref
# .... xref
# ... table-wrap
# .... label
# .... caption
# ..... p
# .... table
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... col
# ..... thead
# ...... tr
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ........ xref
# ......... sup
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ....... th
# ........ xref
# ......... sup
# ....... th
# ........ xref
# ......... sup
# ..... tbody
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ........ xref
# ......... sup
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ........ xref
# ......... sup
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ p
# ........ p
# ......... xref
# .......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ........ xref
# ......... sup
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ......... xref
# .......... sup
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ p
# ........ p
# ......... xref
# .......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ...... tr
# ....... td
# ........ xref
# ......... sup
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ....... td
# ........ bold
# ....... td
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ......... italic
# ....... td
# ....... td
# ....... td
# ........ p
# ........ p
# ....... td
# ........ p
# ........ p
# .... table-wrap-foot
# ..... fn
# ...... label
# ....... sup
# ...... p
# ..... fn
# ...... label
# ....... sup
# ...... p
# ..... fn
# ...... label
# ....... sup
# ...... p
# ..... fn
# ...... label
# ....... sup
# ...... p
# ..... fn
# ...... label
# ....... sup
# ...... p
# ..... fn
# ...... label
# ....... sup
# ...... p
# ..... fn
# ...... label
# ....... sup
# ...... p
# ... fig
# .... label
# .... caption
# ..... p
# .... graphic
# ... sec
# .... label
# .... title
# ..... styled-content
# ..... styled-content
# ..... styled-content
# .... p
# ..... xref
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ..... xref
# .... fig
# ..... label
# ..... caption
# ...... p
# ..... graphic
# ... sec
# .... label
# .... title
# ..... styled-content
# .... p
# ..... xref
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ...... sup
# ..... xref
# ..... xref
# ...... sup
# ..... xref
# .... fig
# ..... label
# ..... caption
# ...... p
# ..... graphic
# ... sec
# .... label
# .... title
# .... p
# ..... italic
# ..... italic
# ..... italic
# ..... xref
# ..... xref
# .... table-wrap
# ..... label
# ..... caption
# ...... p
# ..... table
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... thead
# ....... tr
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ...... tbody
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ......... xref
# .......... sup
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ......... xref
# .......... sup
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ..... table
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... col
# ...... thead
# ....... tr
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ........ th
# ...... tbody
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ....... tr
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ........ td
# ..... table-wrap-foot
# ...... fn
# ....... p
# ...... fn
# ....... label
# ........ sup
# ....... p
# ...... fn
# ....... label
# ........ sup
# ....... p
# .. sec
# ... label
# ... title
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... xref
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... xref
# ..... sup
# .... italic
# .... xref
# ..... sup
# .... xref
# ..... sup
# ... p
# .... xref
# ..... sup
# .... xref
# ..... sup
# .. sec
# ... title
# ... p
# .. sec
# ... title
# ... p
# .. sec
# ... title
# ... supplementary-material
# .... caption
# ..... p
# .... media
# ..... caption
# ...... p
# ... supplementary-material
# .... caption
# ..... p
# .... media
# ..... caption
# ...... p
# ... supplementary-material
# .... caption
# ..... p
# .... media
# ..... caption
# ...... p
# ... supplementary-material
# .... caption
# ..... p
# .... media
# ..... caption
# ...... p
# ... supplementary-material
# .... caption
# ..... p
# .... media
# ..... caption
# ...... p
# ... supplementary-material
# .... caption
# ..... p
# .... media
# ..... caption
# ...... p
# . back
# .. ref-list
# ... title
# ... ref
# .... label
# .... mixed-citation
# ..... collab
# ..... ext-link
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... collab
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... ext-link
# ... ref
# .... label
# .... mixed-citation
# ..... ext-link
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... italic
# ..... year
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... source
# ..... publisher-name
# ..... year
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... elocation-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ...... suffix
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... elocation-id
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... elocation-id
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... ext-link
# ... ref
# .... label
# .... mixed-citation
# ..... ext-link
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... elocation-id
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... elocation-id
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... ext-link
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id
# ... ref
# .... label
# .... mixed-citation
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... string-name
# ...... surname
# ...... given-names
# ..... article-title
# ..... source
# ..... year
# ..... volume
# ..... issue
# ..... fpage
# ..... lpage
# ..... pub-id
# ..... pub-id

# %%
# get_article_text(articles[ 4 ]) # articles[3] has subsections in abstract

# for article in articles: print(get_title(article))

get_all_articles(articles[3:6])
# Out:
#          pmid  paragraph_number                       section_path  \
# 0    36785543                 0                              Title
# 1    36785543                 1             Abstract || Background
# 2    36785543                 2             Abstract || Objectives
# 3    36785543                 3                Abstract || Methods
# 4    36785543                 4                Abstract || Results
# ..        ...               ...                                ...
# 110  36644019                46          Contributorship statement
# 111  36644019                47  Declaration of Competing interest
# 112  36644019                48                            Consent
# 113  36644019                49                            Funding
# 114  36644019                50             Data sharing statement
#
#                                                   text
# 0    Vaccine confidence among those living with all...
# 1    Reports of allergic reactions to coronavirus d...
# 2    Our aim was to review the academic and gray li...
# 3    We searched 4 databases (CINAHL, PsycINFO, MED...
# 4    Of the 1385 unique records retrieved from our ...
# ..                                                 ...
# 110  MG supervised evaluation project, revised data...
# 111  All authors declare that we have no conflicts ...
# 112  All authors consent to publication of this man...
# 113  There was no external funding for this service...
# 114  All data relevant to the study are included in...
#
# [115 rows x 4 columns]

# %%
csv_file = DATA_FILE.replace('.xml', '.csv')

big_article_table = get_all_articles(articles)

big_article_table.to_csv(DATA_DIR + csv_file, index=False)

# %%
import random

sample_PMIDs = random.sample(sorted(set(big_article_table['pmid'])), 3)

example_data = big_article_table[ [row['pmid'] in sample_PMIDs for row in big_article_table.to_dict(orient='records') ] ]

example_data
# Out:
#             pmid  paragraph_number                       section_path  \
# 13182   37327781                 0                              Title
# 13183   37327781                 1                           Abstract
# 13184   37327781                 2                       Introduction
# 13185   37327781                 3                       Introduction
# 13186   37327781                 4                       Introduction
# ...          ...               ...                                ...
# 175683  37783679                43  Methods || ELISA and Western Blot
# 175684  37783679                44   Methods || NAD+/NADH measurement
# 175685  37783679                45       Methods || Reporting summary
# 175686  37783679                46          Supplementary information
# 175687  37783679                47                        Source data
#
#                                                      text
# 13182   Multi-omic longitudinal study reveals immune c...
# 13183   The IMPACC cohort, composed of >1,000 hospital...
# 13184   Throughout the COVID-19 pandemic, scientists w...
# 13185   The clinical manifestations of COVID-19 are di...
# 13186   Here, we carried out deep immunophenotyping of...
# ...                                                   ...
# 175683  Concentration of IL-8 in the cell supernatant ...
# 175684  Total extracellular, intracellular and intraba...
# 175685  Further information on research design is avai...
# 175686  \nSupplementary Information\nPeer Review File\...
# 175687                                    \nSource Data\n
#
# [201 rows x 4 columns]

# %%
example_data.to_csv("example_data.csv", index=False)
